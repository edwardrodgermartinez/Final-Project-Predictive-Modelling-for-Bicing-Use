# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import cm
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.api import SimpleExpSmoothing
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.ar_model import AutoReg
from statsmodels.tools.eval_measures import rmse
from sklearn.linear_model import LinearRegression as LinReg
from sklearn.ensemble import RandomForestRegressor as RFR
from sklearn.ensemble import GradientBoostingRegressor as GBR
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import mean_squared_error
from prophet import Prophet
from prophet.plot import plot_plotly

# %%
df = pd.read_csv("data/bicing_lunes_2.csv")

# %%
df.isna().sum()
# Out:
# dateTime                             0
# bikesInUsage                         0
# electricalBikesInUsage               0
# mechanicalBikesInUsage               0
# is_weekend_or_bank_holiday           0
# is_eve_of_weekend_or_bank_holiday    0
# time_of_day                          0
# temperature_2m                       0
# rain                                 0
# dtype: int64

# %%
df
# Out:
#                  dateTime  bikesInUsage  electricalBikesInUsage  \
# 0     2018-08-01 17:00:00    662.500000               15.000000
# 1     2018-08-01 18:00:00    799.750000               12.250000
# 2     2018-08-01 19:00:00    754.750000                5.000000
# 3     2018-08-01 20:00:00    679.000000                7.000000
# 4     2018-08-01 21:00:00    577.500000                5.000000
# ...                   ...           ...                     ...
# 3650  2018-12-31 19:00:00    266.250000                3.833333
# 3651  2018-12-31 20:00:00    214.083333                2.166667
# 3652  2018-12-31 21:00:00    135.166667                0.500000
# 3653  2018-12-31 22:00:00     75.333333                0.250000
# 3654  2018-12-31 23:00:00     68.416667                0.500000
#
#       mechanicalBikesInUsage  is_weekend_or_bank_holiday  \
# 0                 647.500000                       False
# 1                 787.500000                       False
# 2                 749.750000                       False
# 3                 672.000000                       False
# 4                 572.500000                       False
# ...                      ...                         ...
# 3650              262.416667                       False
# 3651              211.916667                       False
# 3652              134.666667                       False
# 3653               75.083333                       False
# 3654               67.916667                       False
#
#       is_eve_of_weekend_or_bank_holiday time_of_day  temperature_2m  rain
# 0                                 False   Afternoon       30.689999   0.0
# 1                                 False     Evening       30.240000   0.0
# 2                                 False     Evening       28.890000   0.0
# 3                                 False     Evening       27.390000   0.0
# 4                                 False     Evening       26.689999   0.0
# ...                                 ...         ...             ...   ...
# 3650                              False     Evening        7.890000   0.0
# 3651                              False     Evening        7.090000   0.0
# 3652                              False     Evening        6.690000   0.0
# 3653                              False     Evening        6.390000   0.0
# 3654                              False     Evening        6.390000   0.0
#
# [3655 rows x 9 columns]

# %%
df = df[["dateTime", "bikesInUsage"]]

# %%
df.head()
# Out:
#               dateTime  bikesInUsage
# 0  2018-08-01 17:00:00        662.50
# 1  2018-08-01 18:00:00        799.75
# 2  2018-08-01 19:00:00        754.75
# 3  2018-08-01 20:00:00        679.00
# 4  2018-08-01 21:00:00        577.50

# %%
df.columns = ['ds', 'y']

# %%
df.head()
# Out:
#                     ds       y
# 0  2018-08-01 17:00:00  662.50
# 1  2018-08-01 18:00:00  799.75
# 2  2018-08-01 19:00:00  754.75
# 3  2018-08-01 20:00:00  679.00
# 4  2018-08-01 21:00:00  577.50

# %%
df['ds'] = pd.to_datetime(df['ds'])
# Out:
# /var/folders/q9/jkycd7cd6tqdf410bnlz4q2c0000gn/T/ipykernel_45984/3173280147.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ds'] = pd.to_datetime(df['ds'])

# %%
df.tail()
# Out:
#                       ds           y
# 3650 2018-12-31 19:00:00  266.250000
# 3651 2018-12-31 20:00:00  214.083333
# 3652 2018-12-31 21:00:00  135.166667
# 3653 2018-12-31 22:00:00   75.333333
# 3654 2018-12-31 23:00:00   68.416667

# %%
df.plot(x='ds', y='y', figsize = (18, 6))
# Out:
# <Axes: xlabel='ds'>

# %%
len(df)
# Out:
# 3655

# %%
train = df.iloc[:len(df)- 731]
test = df.iloc[len(df)- 731:]

# %%
m = Prophet()
m.fit(train)
future = m.make_future_dataframe(periods = 731, freq = 'H')
forecast = m.predict(future)
# Out:
# 23:11:23 - cmdstanpy - INFO - Chain [1] start processing
# 23:11:23 - cmdstanpy - INFO - Chain [1] done processing

# %%
forecast.tail()
# Out:
#                       ds       trend  yhat_lower  yhat_upper  trend_lower  \
# 3650 2018-12-31 19:00:00  335.439370  440.005928  793.262721   312.350514
# 3651 2018-12-31 20:00:00  335.440970  387.961201  745.827821   312.302807
# 3652 2018-12-31 21:00:00  335.442570  260.494132  622.789434   312.255099
# 3653 2018-12-31 22:00:00  335.444171  160.127735  527.239120   312.207392
# 3654 2018-12-31 23:00:00  335.445771   71.950934  434.572960   312.159684
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 3650   358.140274      281.171322            281.171322            281.171322
# 3651   358.184806      225.925705            225.925705            225.925705
# 3652   358.232443      111.462442            111.462442            111.462442
# 3653   358.280079       -6.642472             -6.642472             -6.642472
# 3654   358.327716      -75.504249            -75.504249            -75.504249
#
#            daily  daily_lower  daily_upper     weekly  weekly_lower  \
# 3650  253.865937   253.865937   253.865937  27.305385     27.305385
# 3651  195.967732   195.967732   195.967732  29.957972     29.957972
# 3652   79.048024    79.048024    79.048024  32.414418     32.414418
# 3653  -41.318953   -41.318953   -41.318953  34.676481     34.676481
# 3654 -112.251435  -112.251435  -112.251435  36.747186     36.747186
#
#       weekly_upper  multiplicative_terms  multiplicative_terms_lower  \
# 3650     27.305385                   0.0                         0.0
# 3651     29.957972                   0.0                         0.0
# 3652     32.414418                   0.0                         0.0
# 3653     34.676481                   0.0                         0.0
# 3654     36.747186                   0.0                         0.0
#
#       multiplicative_terms_upper        yhat
# 3650                         0.0  616.610691
# 3651                         0.0  561.366675
# 3652                         0.0  446.905013
# 3653                         0.0  328.801699
# 3654                         0.0  259.941522

# %%
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#                       ds        yhat  yhat_lower  yhat_upper
# 3650 2018-12-31 19:00:00  616.610691  440.005928  793.262721
# 3651 2018-12-31 20:00:00  561.366675  387.961201  745.827821
# 3652 2018-12-31 21:00:00  446.905013  260.494132  622.789434
# 3653 2018-12-31 22:00:00  328.801699  160.127735  527.239120
# 3654 2018-12-31 23:00:00  259.941522   71.950934  434.572960

# %%
predictions = forecast.iloc[-731:]['yhat']

# %%
print("RMSE: ", rmse(predictions,test['y']))
print("r2: ", metrics.r2_score(predictions,test['y']))
# Out:
# RMSE:  143.051645180671
# r2:  0.2698663591408078
